# %% [markdown]
# # Matplotlib
# https://www.w3schools.com/python/matplotlib_intro.asp

# %%
#install matplotlib
#!pip install matplotlib

# %%
import matplotlib

# 1.1 print version of matplotlib
# Out:
# 3.8.0

# %% [markdown]
# # Matplotlib Pyplot
# most of the Matplotlib utilities lies in the pyplot submodule

# %%
#import plplot submodule as alias plt
import matplotlib.pyplot as plt

import numpy as np

# %% [markdown]
# # Matplotlib Plotting
# plot() function : parameter 1 is an array of points on the x-axis, parameter 2 is an array of points on the y-axis

# %% [markdown]
# # Line
# **line style** : *linestyle* or *ls*,
# **line colour** : *color* or *c*, **line width** : *linewidth* or *lw*

# %%
xpoints = np.array([3, 4, 6, 8])
ypoints = np.array([3, 1, 10, 80])

#2.1 create a line plot. x-axis has xpoints, y-axis has ypoints

# %% [markdown]
# Markers: https://www.w3schools.com/python/matplotlib_markers.asp

# %%
xpoints = np.array([3, 4, 6, 8])
ypoints = np.array([3, 1, 10, 80])

# 2.2 create a dashed line plot. x-axis has xpoints, y-axis has ypoints. use a square marker for points.

# %% [markdown]
# **Format strings**
# (shortcut string notation) : *marker*|*line*|*colour*

# %% [markdown]
# **Multiple lines**

# %% [markdown]
# # Labels

# %%
xpoints = np.array([30, 40, 60, 80])
ypoints = np.array([3, 1, 10, 80])

# 2.3 create a dashed line plot. x-axis has xpoints, y-axis has ypoints. set title='Sports Watch Data', x-axis label='Average Pulse', y-axis label='Calorie Burnage'
#

# %% [markdown]
# # Multiple plots in one figure : subplot()

# %% [markdown]
# https://www.w3schools.com/python/matplotlib_subplot.asp
#
# The subplot() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.

# %%
# 2.4 figure with two rows and two columns

#2.4.1: plot 1: line plot location is row 1 column 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])




#2.4.2: plot 2: line plot location is row 1 column 2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])


#2.4.3: plot 3: line plot location is row 2 column 1
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])



#2.4.4: plot 4:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])




plt.suptitle("MY SHOP") #supertitle

plt.show()

# %% [markdown]
# # Scatter
# **scatter()**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,14,12,12,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

# 2.5 scatterplot x-axis=x, y-axis=y

# %% [markdown]
# # Bars

# %%
x = np.array(["A", "B", "C"])
y = np.array([3, 8, 1])

# 2.5 bar plot, x-axis=x, y-axis=y, colour is red

# %% [markdown]
# **Colour names: https://www.w3schools.com/colors/colors_names.asp**

# %% [markdown]
# **Horizontal bar**

# %% [markdown]
# **Histogram : frequency distribution**

# %%
#generate an array of 200 random numbers where the values are around 100, and the standard deviation is 20
x = np.random.normal(100, 20, 200)

print(x)
# Out:
# [107.01418961 156.25994443  85.16523696  70.75638899 109.70182195
#  105.36166715  77.20157141  70.6045518   89.51559422  92.20090978
#   90.22750353  72.27734266  98.50150665  98.93316533  85.20878613
#   72.64750897 111.48905724  89.18909652  98.46445926 110.31913123
#  133.47261922 106.16503819  95.98114662  95.73283274 141.34834198
#   86.09723478 100.71713696 108.37151847 101.88611392  80.54483355
#  109.92083086  91.02201019  87.57132609 130.66300022 115.47351774
#   87.65229001  45.76078184  78.62275565 100.64872029 101.10298749
#   86.82249058  92.6877572   70.22713611 131.66876016  55.22642658
#  107.25214983  83.00088936  92.69840679 100.18286613  99.48401034
#  120.92857116 137.12065585 105.43172457  94.34801452  92.43199996
#  100.61080564 113.42390835  57.27777956  86.82438916  74.95495035
#  112.05596259  67.41186514  79.48050544 102.08400821  87.95384384
#  112.3701998  117.65850733  76.7776199   65.61092528  99.9364961
# ...

# %%
#generate an array of 200 random numbers where the values are around 100, and the standard deviation is 20
x = np.random.normal(100, 20, 200)

#2.6 draw histogram for x
